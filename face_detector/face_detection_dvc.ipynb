# %%
# !pip3 install dvc

# %%
# !pip3 install 'dvc[gdrive]'

# %%
# username and key required if the repo is private
# !git clone "https://github.com/se4ai2122-cs-uniba/AgeGuesser.git"

# %%
# %cd AgeGuesser/face_detector/
# Out:
# /content/AgeGuesser/face_detector

# %%
# !git checkout 35-enhancement-dvcvalid
# Out:
# Branch '35-enhancement-dvcvalid' set up to track remote branch '35-enhancement-dvcvalid' from 'origin'.
# Switched to a new branch '35-enhancement-dvcvalid'

# %%
# !dvc pull

# %%
# !rm -r dataset

# %%
# !git config --global user.name "n1CkS4x0"

# %%
# !git config --global user.email "n.marvulli1@studenti.uniba.it"

# %%
# !pip3 install mlflow
# !pip3 install google_utils
# !pip3 install -qr requirements.txt

# %%
# !dvc dag

# %%
#!rm -rf .dvc/tmp/rwlock
# !pip3 install great_expectations

# %%
# !rm -r .dvc/cache

# %%
# !dvc exp run -S train.epochs=50
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: dataset/yolo/labels/12_Group_Group_12_Group_Group_12_657.txt
#   inflating: dataset/yolo/labels/12_Group_Group_12_Group_Group_12_615.txt
#   inflating: dataset/yolo/labels/12_Group_Large_Group_12_Group_Large_Group_12_260.txt
#   inflating: dataset/yolo/labels/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_938.txt
#   inflating: dataset/yolo/labels/12_Group_Large_Group_12_Group_Large_Group_12_66.txt
#   inflating: dataset/yolo/labels/12_Group_Large_Group_12_Group_Large_Group_12_118.txt
#   inflating: dataset/yolo/labels/12_Group_Large_Group_12_Group_Large_Group_12_752.txt
#   inflating: dataset/yolo/labels/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_833.txt
#   inflating: dataset/yolo/labels/12_Group_Group_12_Group_Group_12_104.txt
#   inflating: dataset/yolo/labels/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_828.txt
# ...

# %%
#!python3 train.py --data "dataset/yolo/data.yaml" --cfg ./models/yolov5s.yaml --weights "yolov5s.pt" --name results  --cache

# %%
#!git add models/yolov5s.yaml dvc.lock yolov5s.pt detect.py train.py runs/train/results/weights/.gitignore runs/detect/.gitignore dataset/yolo/data.yaml params.yaml dvc.yaml

# %%
#!dvc push

# %%
#!dvc status
